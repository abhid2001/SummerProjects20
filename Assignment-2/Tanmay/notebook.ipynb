# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df=df.dropna(axis=1,thresh=292)

# %%
df['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
df.LotFrontage.median()
# Out:
# 69.0

# %%
df.LotFrontage.fillna('69.0',inplace=True)

# %%
df.MasVnrType.value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
df.MasVnrType.fillna('BrkFace',inplace=True)

# %%
df.MasVnrArea.median()
# Out:
# 0.0

# %%
df.MasVnrArea.fillna('0.0',inplace=True)

# %%
df.MSZoning.value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
df.MSZoning.fillna('0.0',inplace=True)

# %%
df.BsmtQual.value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
df.BsmtQual.fillna('TA',inplace=True)

# %%
df.BsmtCond.fillna('TA',inplace=True)

# %%
df.BsmtExposure.fillna('No',inplace=True)

# %%
df.BsmtFinType2.fillna('Unf',inplace=True)

# %%
df.BsmtFinType1.value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
df.BsmtFinType1.fillna('Unf',inplace=True)

# %%
df.FireplaceQu.value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
df.FireplaceQu.fillna('Gd',inplace=True)

# %%
df.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-986e25863b45> in <module>
# ----> 1 df.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
df.GarageType.fillna('Attchd',inplace=True)

# %%
df.GarageYrBlt.value_counts()
# Out:
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
#           ..
# 1908.0     1
# 1927.0     1
# 1933.0     1
# 1900.0     1
# 1906.0     1
# Name: GarageYrBlt, Length: 97, dtype: int64

# %%
df.GarageYrBlt.value_counts().max()
# Out:
# 65

# %%
df.GarageYrBlt.fillna('2005.0',inplace=True)

# %%
df.GarageFinish.value_counts()
# Out:
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64

# %%
df.GarageFinish.fillna('Unf',inplace=True)

# %%
df.GarageQual.value_counts()
# Out:
# TA    1311
# Fa      48
# Gd      14
# Po       3
# Ex       3
# Name: GarageQual, dtype: int64

# %%
df.GarageQual.fillna('TA',inplace=True)

# %%
df.GarageCond.value_counts()
# Out:
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64

# %%
df.GarageCond.fillna('TA',inplace=True)

# %%
df.Electrical.fillna('SBrkr',inplace=True)

# %%
df.LotFrontage.value_counts()
# Out:
# 69.0     259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
#         ...
# 138.0      1
# 137.0      1
# 112.0      1
# 111.0      1
# 182.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %%
df=pd.get_dummies(df,columns=['Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Condition1','Condition2','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrArea','ExterQual','ExterCond','Foundation','FireplaceQu','GarageType','GarageYrBlt','BldgType','MasVnrType','KitchenQual','Functional','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType2','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','FireplaceQu','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond','Electrical','SaleType','PavedDrive','Neighborhood','SaleCondition'])

# %%
df.MSZoning
# Out:
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: object

# %%
df=pd.get_dummies(df,columns=['MSZoning'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-7aa8c452411a> in <module>
# ----> 1 df=pd.get_dummies(df,columns=['MSZoning'])
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     866             raise TypeError("Input must be a list-like for parameter `columns`")
#     867         else:
# --> 868             data_to_encode = data[columns]
#     869
#     870         # validate prefixes and separator to avoid silently dropping cols
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 1560 entries, SalePrice to MSZoning_RM
# dtypes: int64(35), object(1), uint8(1524)
# memory usage: 2.5+ MB

# %%
import matplotlib.pyplot as plt

# %%
y=df["SalePrice"]
x=df.loc[ :,df.columns!='SalePrice']

# %%
y=y.to_numpy()
y=y.reshape(Y.shape[0],1)
x=x.to_numpy()
x
# Out:
# array([[1, 60, 65.0, ..., 0, 1, 0],
#        [2, 20, 80.0, ..., 0, 1, 0],
#        [3, 60, 68.0, ..., 0, 1, 0],
#        ...,
#        [1458, 70, 66.0, ..., 0, 1, 0],
#        [1459, 20, 68.0, ..., 0, 1, 0],
#        [1460, 20, 75.0, ..., 0, 1, 0]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
x_test
# Out:
# array([[530, 20, '69.0', ..., 0, 1, 0],
#        [492, 50, 79.0, ..., 0, 1, 0],
#        [460, 50, '69.0', ..., 0, 1, 0],
#        ...,
#        [1391, 20, 70.0, ..., 0, 1, 0],
#        [1376, 20, 89.0, ..., 0, 1, 0],
#        [639, 30, 67.0, ..., 0, 1, 0]], dtype=object)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=regressor.predict(x_test)

# %%
y_pred
# Out:
# array([[ 2.46426900e+05],
#        [ 1.48087025e+05],
#        [-2.23650917e+07],
#        [-2.22800367e+07],
#        [-2.24151537e+07],
#        [ 9.02910248e+04],
#        [ 2.38818525e+05],
#        [ 1.22740775e+05],
#        [ 5.10326025e+05],
#        [ 1.61748150e+05],
#        [ 2.10217275e+05],
#        [ 6.23043183e+08],
#        [ 2.41543150e+05],
#        [ 1.14127025e+05],
#        [ 9.42684623e+04],
#        [ 1.46169275e+05],
#        [ 2.48333494e+05],
#        [ 1.36280775e+05],
#        [ 1.42921525e+05],
#        [ 1.75151275e+05],
#        [ 1.30214775e+05],
#        [ 1.85528025e+05],
#        [ 8.14090248e+04],
#        [ 1.54600275e+05],
#        [ 1.59438150e+05],
#        [ 1.45523775e+05],
#        [ 1.70129900e+05],
#        [ 6.78962748e+04],
#        [ 3.38010775e+05],
#        [-1.68093818e+09],
#        [ 1.67331525e+05],
#        [-2.22627357e+07],
#        [ 1.40547525e+05],
#        [ 3.09385900e+05],
#        [-2.21285225e+07],
# ...

# %%
y_test
# Out:
# array([[200624],
#        [133000],
#        [110000],
#        [192000],
#        [ 88000],
#        [ 85000],
#        [282922],
#        [141000],
#        [745000],
#        [148800],
#        [208900],
#        [136905],
#        [225000],
#        [123000],
#        [119200],
#        [145000],
#        [190000],
#        [123600],
#        [149350],
#        [155000],
#        [166000],
#        [144500],
#        [110000],
#        [174000],
#        [185000],
#        [168000],
#        [177500],
#        [ 84500],
#        [320000],
#        [118500],
#        [110000],
#        [213000],
#        [156000],
#        [250000],
#        [372500],
#        [175000],
#        [277500],
#        [112500],
#        [263000],
#        [325000],
#        [243000],
#        [130000],
#        [164990],
#        [280000],
#        [403000],
#        [119000],
#        [125000],
#        [128200],
#        [172500],
#        [ 84900],
#        [412500],
#        [156000],
# ...

# %%
xtest=pd.read_csv('test.csv')

# %%
xtest
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
xtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
xtest=xtest.dropna(axis=1,thresh=292)

# %%
xtest.LotFrontage.median()
# Out:
# 67.0

# %%
xtest.LotFrontage.fillna('67.0',inplace=True)

# %%
xtest.MasVnrType.value_counts()
# Out:
# None       878
# BrkFace    450
# Stone      121
# BrkCmn      10
# Name: MasVnrType, dtype: int64

# %%
xtest.MasVnrType.fillna('BrkFace',inplace=True)

# %%
xtest.MasVnrArea.median()
# Out:
# 0.0

# %%
xtest.MasVnrArea.fillna('0.0',inplace=True)

# %%
xtest.MSZoning.fillna('0.0',inplace=True)

# %%
xtest.BsmtQual.fillna('TA',inplace=True)

# %%
xtest.BsmtCond.fillna('TA',inplace=True)

# %%
xtest.BsmtExposure.fillna('No',inplace=True)

# %%
xtest.BsmtFinType2.fillna('Unf',inplace=True)

# %%
xtest.BsmtFinType1.fillna('Unf',inplace=True)

# %%
xtest.FireplaceQu.fillna('Gd',inplace=True)

# %%
xtest.GarageType.fillna('Attchd',inplace=True)

# %%
xtest.GarageYrBlt.fillna('2005.0',inplace=True)

# %%
xtest.GarageFinish.fillna('Unf',inplace=True)

# %%
xtest.GarageQual.fillna('TA',inplace=True)

# %%
xtest.GarageCond.fillna('TA',inplace=True)

# %%
xtest.Electrical.fillna('SBrkr',inplace=True)

# %%
xtest=pd.get_dummies(xtest,columns=['Street','LotShape','LandContour','Utilities','MSZoning','LotConfig','LandSlope','Condition1','Condition2','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrArea','ExterQual','ExterCond','Foundation','FireplaceQu','GarageType','GarageYrBlt','BldgType','MasVnrType','KitchenQual','Functional','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType2','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','FireplaceQu','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond','Electrical','SaleType','PavedDrive','Neighborhood','SaleCondition'])

# %%
xtest
# Out:
#         Id  MSSubClass LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1461          20          80    11622            5            6
# 1     1462          20          81    14267            6            6
# 2     1463          60          74    13830            5            5
# 3     1464          60          78     9978            6            6
# 4     1465         120          43     5005            8            5
# ...    ...         ...         ...      ...          ...          ...
# 1454  2915         160          21     1936            4            7
# 1455  2916         160          21     1894            4            5
# 1456  2917          20         160    20000            5            7
# 1457  2918          85          62    10441            5            5
# 1458  2919          60          74     9627            7            5
#
#       YearBuilt  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  ...  \
# 0          1961          1961       468.0       144.0  ...
# ...

# %%
xtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Columns: 776 entries, Id to SaleCondition_Partial
# dtypes: float64(8), int64(26), object(1), uint8(741)
# memory usage: 1.4+ MB

# %%
xtest.shape
# Out:
# (1459, 776)

# %%
xtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Columns: 776 entries, Id to SaleCondition_Partial
# dtypes: float64(8), int64(26), object(1), uint8(741)
# memory usage: 1.4+ MB

# %%
xtest
# Out:
#         Id  MSSubClass LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1461          20          80    11622            5            6
# 1     1462          20          81    14267            6            6
# 2     1463          60          74    13830            5            5
# 3     1464          60          78     9978            6            6
# 4     1465         120          43     5005            8            5
# ...    ...         ...         ...      ...          ...          ...
# 1454  2915         160          21     1936            4            7
# 1455  2916         160          21     1894            4            5
# 1456  2917          20         160    20000            5            7
# 1457  2918          85          62    10441            5            5
# 1458  2919          60          74     9627            7            5
#
#       YearBuilt  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  ...  \
# 0          1961          1961       468.0       144.0  ...
# ...

# %%
xtest=xtest.to_numpy()

# %%
from sklearn.linear_model import LinearRegression

# %%
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-346-9261bfc5ce37> in <module>
# ----> 1 pred=reg.predict(xtest)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     203
#     204     def _decision_function(self, X):
# --> 205         check_is_fitted(self)
#     206
#     207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     965
#     966     if not attrs:
# ...

# %%
regressor=LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
